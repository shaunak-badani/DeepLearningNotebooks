# %%
import torch

# %%
X = torch.randn(1000, 3, 224, 224)
y = torch.randint(high = 10, size = (1000, 1))

# %%
X
# Out:
# tensor([[[[ 1.3705,  0.6051,  1.2858,  ...,  0.2807, -1.0959, -0.1366],
#           [ 0.6618,  0.6014, -0.0184,  ..., -0.2099,  0.3909,  0.0725],
#           [ 2.0591, -0.2654,  1.4612,  ...,  1.4920,  1.2993, -0.3555],
#           ...,
#           [ 0.1677,  0.3535, -1.5958,  ...,  0.9162, -0.5334,  0.3618],
#           [-0.1525, -0.9148, -0.3643,  ...,  0.2596, -0.2769,  0.6321],
#           [-0.1849, -0.0162,  0.5217,  ..., -0.8133, -0.0057,  0.1882]],
#
#          [[ 0.0270, -2.2552,  2.2557,  ..., -0.7314, -1.5002, -0.6463],
#           [-0.9750,  0.6891,  0.2943,  ..., -2.2388, -0.8903,  0.8536],
#           [ 0.0903, -1.1919,  0.1378,  ..., -1.3493,  1.0794, -0.3610],
#           ...,
#           [ 2.3223, -0.4160,  0.7376,  ..., -2.3104,  0.7763,  1.2626],
#           [-0.0153,  0.5030, -0.0179,  ..., -0.4579,  1.6702,  1.7451],
#           [-0.7831, -0.1621, -0.2156,  ...,  0.1061, -0.4894, -0.5558]],
#
# ...

# %%
y
# Out:
# tensor([[3],
#         [7],
#         [9],
#         [6],
#         [4],
#         [9],
#         [3],
#         [9],
#         [6],
#         [1],
#         [6],
#         [2],
#         [6],
#         [6],
#         [3],
#         [7],
#         [1],
#         [1],
#         [8],
#         [7],
#         [0],
#         [8],
#         [0],
#         [6],
#         [8],
#         [1],
#         [5],
#         [5],
#         [2],
#         [0],
#         [3],
#         [6],
#         [8],
#         [5],
#         [4],
#         [4],
#         [6],
#         [6],
#         [9],
#         [6],
#         [0],
#         [6],
#         [3],
#         [4],
#         [8],
#         [2],
#         [3],
#         [4],
#         [0],
#         [4],
#         [0],
#         [2],
#         [6],
#         [8],
#         [2],
#         [8],
#         [4],
#         [0],
#         [0],
#         [2],
#         [3],
#         [9],
#         [8],
#         [1],
#         [0],
#         [6],
# ...
